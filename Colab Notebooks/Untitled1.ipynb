# %%
2+3
# Out:
# 5

# %%
print("hello python")
# Out:
# hello python

# %%
x=10
y=20
z=x+y
print(z)
# Out:
# 30

# %%
print('Python')
print("Python")
print('''Python''')
print("""Python""")
# Out:
# Python
# Python
# Python
# Python

# %%
name="srinivas "
print(name)
print(name+ '::' +name)
print(name*4)
# Out:
# srinivas
# srinivas ::srinivas
# srinivas srinivas srinivas srinivas

# %%
print("My name is ..",name)
# Out:
# My name is .. srinivas

# %%
first_num=10
print("first number is ..",first_num)
second_num=20
print('second number is..',second_num)
print("addition of two numbers is ...",first_num+second_num)
# Out:
# first number is .. 10
# second number is.. 20
# addition of two numbers is ... 30

# %%
# type() funtion is get data type of the variable
x=10
type(x)
# Out:
# int

# %%
y=10.56
type(y)
# Out:
# float

# %%
name="srinivas"
type(name)
# Out:
# str

# %%
names=['ayswarya','spandana','manogna','sanath']
print(names)
# Out:
# ['ayswarya', 'spandana', 'manogna', 'sanath']

# %%
type(names)
# Out:
# list

# %%
names1=('ayswarya','spandana','manogna','sanath')
type(names1)
# Out:
# tuple

# %%
names3 = {'ayswarya','spandana','manogna','sanath'}
type(names3)
# Out:
# set

# %%
isMarried=True
type(isMarried)
# Out:
# bool

# %%
name=input('enter ur name')
name
# Out:
# enter ur namesrinivas
# 'srinivas'

# %%
age=input('enter ur age')
age
# Out:
# enter ur age32
# '32'

# %%
print("my name is ..",name)
print('my age is ..',age)
# Out:
# my name is .. srinivas
# my age is .. 32

# %%
# small price calculation
prd_price=input("enter product price") # '45000'
prd_dis= input("enter discount price") # '3330'
final_price = int(prd_price)- int(prd_dis)
print("final price of the product is ...",final_price)
# Out:
# enter product price45000
# enter discount price3330
# final price of the product is ... 41670
