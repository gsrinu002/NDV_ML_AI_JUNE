# %%
2+3
# Out:
# 5

# %%
34*45
# Out:
# 1530

# %%
456/89
# Out:
# 5.123595505617978

# %%
34**4 # power
# Out:
# 1336336

# %%
2**3
# Out:
# 8

# %%
x=10
y=20
sum=x+y
sum
# Out:
# 30

# %%
f_num = int(input("enter first number"))
s_num = int(input("enter second number"))
# input function will take input type as string
# we need to convert string to int

summation =f_num+s_num
summation
# Out:
# enter first number12
# enter second number13
# 25
